# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/churnsense-customer-churn/blob/main/ChurnSense_AI_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *

# %%
# ==========================================
# CHURNSENSE MASTER LAUNCHER (V3 - Final)
# ==========================================
import os
import subprocess
import time

# 1. Clone & Install
print("🛠️ Setting up environment...")
REPO_URL = "https://github.com/aryan12375/churnsense-customer-churn"

if not os.path.exists('src'):
    # !git clone {REPO_URL} temp_repo
    # !cp -r temp_repo/* .
    # !cp -r temp_repo/.* .
    # !rm -rf temp_repo

# Fix: Add current directory to Python Path
os.environ['PYTHONPATH'] += f":{os.getcwd()}"

if os.path.exists('requirements.txt'):
    # !pip install -q -r requirements.txt
    # !pip install -q pyngrok shap mlflow
    # !npm install -g localtunnel
    print("✅ Dependencies installed.")

# 2. Run Pipeline
print("\n📊 Training models and generating SHAP reports...")
# !python src/train.py
# !python src/shap_explain.py --top-n 50

# 3. Setup & Launch Dashboard
print("\n🚀 Starting ChurnSense Dashboard...")
os.makedirs('dashboard/public/reports', exist_ok=True)

if os.path.exists('reports/high_risk_customers.json'):
    # !cp reports/high_risk_customers.json dashboard/public/reports/
    print("✅ Data exported to dashboard.")
else:
    print("⚠️ Warning: Report not found. Dashboard will use mock data.")

print("Installing dashboard dependencies...")
# !cd dashboard && npm install -s

print("\n✨ DASHBOARD LIVE AT THE URL BELOW:")
subprocess.Popen(["npm", "run", "dev", "--", "--port", "5173"], cwd="dashboard")
time.sleep(5)

# !lt --port 5173
# Out:
# 🛠️ Setting up environment...
# ⠙⠹⠸⠼⠴
# changed 22 packages in 649ms
# ⠴
# ⠴3 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴✅ Dependencies installed.
#
# 📊 Training models and generating SHAP reports...
# INFO | ── Starting preprocessing pipeline ──────────────────
# Traceback (most recent call last):
#   File "/content/src/train.py", line 268, in <module>
#     main()
#   File "/content/src/train.py", line 264, in main
#     trainer.run(csv_path=args.data)
#   File "/content/src/train.py", line 97, in run
#     X_train, X_test, y_train, y_test, feature_names = prep.run(csv_path)
#                                                       ^^^^^^^^^^^^^^^^^^
#   File "/content/src/preprocessing.py", line 101, in run
#     df = self._load(csv_path)
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/content/src/preprocessing.py", line 140, in _load
#     raise FileNotFoundError(
# FileNotFoundError: Dataset not found at 'data/telco_churn.csv'.
# ...
